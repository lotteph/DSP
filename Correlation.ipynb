# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="white")

# %%
complete_df = pd.read_csv("Complete dataframe/data_preprocessing.csv")

# %%
complete_df["Datetime"] = pd.to_datetime(complete_df["Datetime"])
complete_df = complete_df.set_index("Datetime")
complete_df_2021_2022 = complete_df.loc['2021':'2022'].drop(columns=['Year'])
complete_df_2021_2022.head()
# Out:
#                Location  Visits        Date      Time   Journeys  Windspeed  \
# Datetime
# 2021-01-01   Amstelpark    25.0  2021-01-01  00:00:00  21.818182        2.0
# 2021-01-01  Beatrixpark   154.0  2021-01-01  00:00:00  88.000000        2.0
# 2021-01-01  Erasmuspark   323.0  2021-01-01  00:00:00  13.933333        2.0
# 2021-01-01    Flevopark    65.0  2021-01-01  00:00:00  61.777778        2.0
# 2021-01-01  Gaasperpark    25.0  2021-01-01  00:00:00  15.400000        2.0
#
#             Temperature  Clouds  Rain amount  Rain duration  ...  \
# Datetime                                                     ...
# 2021-01-01         -0.4     1.0          0.0            0.0  ...
# 2021-01-01         -0.4     1.0          0.0            0.0  ...
# 2021-01-01         -0.4     1.0          0.0            0.0  ...
# 2021-01-01         -0.4     1.0          0.0            0.0  ...
# 2021-01-01         -0.4     1.0          0.0            0.0  ...
#
# ...

# %%
# Compute the correlation matrix
corr = complete_df_2021_2022.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
complete_df_2021_2022.corr()
# Out:
#                                                       Visits  Journeys  \
# Visits                                              1.000000  0.500304
# Journeys                                            0.500304  1.000000
# Windspeed                                           0.090516  0.078683
# Temperature                                         0.184027  0.112569
# Clouds                                              0.008170  0.028042
# Rain amount                                        -0.002625  0.009168
# Rain duration                                      -0.006075  0.020376
# Sun duration                                        0.201004  0.138379
# Fog                                                -0.046221 -0.026715
# Rain                                               -0.001078  0.040238
# Snow                                               -0.007301 -0.014008
# Thunder                                             0.020429  0.020136
# ...

# %%
# Too many datapoints, take a random sample to show correlations
sample_df = complete_df_2021_2022.sample(20000)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.scatterplot(data=sample_df, x="Journeys", y="Visits", hue="Location");

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.scatterplot(data=sample_df, x="Temperature", y="Visits", hue="Location");

# %%
f, axes = plt.subplots(2, 2, figsize=(15, 15))

sns.scatterplot(x="Journeys", y="Visits", data=sample_df, ax=axes[0][0], legend=False)
sns.scatterplot(x="Temperature", y="Visits", data=sample_df, ax=axes[0][1])
sns.boxplot(x="stringency_index", y="Visits", data=sample_df, ax=axes[1][0])
xlabels = ['{:,.2f}'.format(x) for x in axes[1][0].get_xticks()/1]
axes[1][0].set_xticklabels(xlabels)
axes[1][0].set(ylim=(0, 750), xlabel="COVID Stringency Index")
sns.boxplot(x="Sun duration", y="Visits", data=sample_df, ax=axes[1][1])
axes[1][1].set(ylim=(0, 750))
# Out:
# [(0.0, 750.0)]
