# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob
import seaborn as sns
import os
import datetime as dt
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
sns.set_context("poster") 
plt.style.use('seaborn-poster')

# %% [markdown]
# # Install XGBoost

# %%
# !pip install xgboost

# %% [markdown]
# # Getting the data

# %%
resono_data = pd.read_csv('helloaimi.csv')
resono_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/3y/wg1nvwfd2fgfgy_dxxxkcbsw0000gn/T/ipykernel_11059/3504661159.py in <module>
# ----> 1 resono_data = pd.read_csv('helloaimi.csv')
#       2 resono_data
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
resono_data = resono_data[['Location', 'Start', 'Start_Dates', 'Start_Time', 'Visits']]
resono_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3y/wg1nvwfd2fgfgy_dxxxkcbsw0000gn/T/ipykernel_11059/3567227722.py in <module>
# ----> 1 resono_data = resono_data[['Location', 'Start', 'Start_Dates', 'Start_Time', 'Visits']]
#       2 resono_data
#
# NameError: name 'resono_data' is not defined

# %%
# path = "Data/Resono/2020-10-18/10/"
# filenames = glob.glob(path + "*.csv")
# resono_data_old = pd.concat((pd.read_csv(file) for file in filenames), ignore_index = True)
# # vondelpark = resono_data[(resono_data['Location'] == 'Vondelpark West')]

# resono_data_old

# %% [markdown]
# # Cleaning the data

# %%
df = resono_data.copy()
df.drop_duplicates(inplace=True)
df['Visits'] = pd.to_numeric(df["Visits"], downcast="integer")
df[df['Location'] == 'Oosterpark'].sort_values(by="Start")
# Out:
#            Location                      Start Start_Dates Start_Time  Visits
# 996      Oosterpark  2020-09-30T00:00:00+00:00  2020-09-30   00:00:00       4
# 997      Oosterpark  2020-09-30T00:15:00+00:00  2020-09-30   00:15:00       3
# 998      Oosterpark  2020-09-30T00:30:00+00:00  2020-09-30   00:30:00       2
# 999      Oosterpark  2020-09-30T00:45:00+00:00  2020-09-30   00:45:00       2
# 1000     Oosterpark  2020-09-30T01:00:00+00:00  2020-09-30   01:00:00       1
# ...             ...                        ...         ...        ...     ...
# 5283726  Oosterpark  2020-12-31T22:45:00+00:00  2020-12-31   22:45:00      65
# 5284526  Oosterpark  2020-12-31T22:45:00+00:00  2020-12-31   22:45:00     122
# 5284527  Oosterpark  2020-12-31T23:00:00+00:00  2020-12-31   23:00:00     110
# 5285400  Oosterpark  2020-12-31T23:15:00+00:00  2020-12-31   23:15:00      95
# 5286212  Oosterpark  2020-12-31T23:30:00+00:00  2020-12-31   23:30:00      92
#
# [13206 rows x 5 columns]

# %%
# Some entries are duplicate, so we need to take the average
df_average_visits = df 
df_average_visits['Start'] = pd.to_datetime(df_average_visits['Start'])
df_average_visits = df_average_visits.groupby(['Location', 'Start', 'Start_Dates', 'Start_Time']).mean().reset_index()
df_average_visits['End'] = df_average_visits['Start'] + dt.timedelta(minutes=14, seconds=59)

df_average_visits
# Out:
#                  Location                     Start Start_Dates Start_Time  \
# 0                Aalsmeer 2020-11-12 00:00:00+00:00  2020-11-12   00:00:00
# 1                Aalsmeer 2020-11-12 00:15:00+00:00  2020-11-12   00:15:00
# 2                Aalsmeer 2020-11-12 00:30:00+00:00  2020-11-12   00:30:00
# 3                Aalsmeer 2020-11-12 00:45:00+00:00  2020-11-12   00:45:00
# 4                Aalsmeer 2020-11-12 01:00:00+00:00  2020-11-12   01:00:00
# ...                   ...                       ...         ...        ...
# 2737962  westergasfabriek 2020-12-31 22:30:00+00:00  2020-12-31   22:30:00
# 2737963  westergasfabriek 2020-12-31 22:45:00+00:00  2020-12-31   22:45:00
# 2737964  westergasfabriek 2020-12-31 23:00:00+00:00  2020-12-31   23:00:00
# 2737965  westergasfabriek 2020-12-31 23:15:00+00:00  2020-12-31   23:15:00
# 2737966  westergasfabriek 2020-12-31 23:30:00+00:00  2020-12-31   23:30:00
#
#          Visits                       End
# ...

# %%
def search_locations(search):
    # boolean series returned with False at place of NaN
    bool_series = df_average_visits["Location"].str.lower().str.contains(search)
    
    # return list of search result
    return df_average_visits[bool_series]['Location'].unique().tolist()

search_locations('park')
# Out:
# ['Amstelpark',
#  'ArenaPark',
#  'Baanakkerspark',
#  'Beatrixpark',
#  'Bella Vistapark',
#  'Bijlmerpark West',
#  'Bilderdijkpark',
#  'Botteskerkpark',
#  'Brand Dirk Ochsepark',
#  'Diemerpark',
#  'Dijkpark',
#  'Ed Pelsterpark',
#  'Eendrachtspark',
#  'Erasmuspark',
#  'Flevopark',
#  'Gaasperpark',
#  'Gerbrandypark',
#  'Gijsbrecht van Aemstelpark',
#  'Grote Rieteiland Park',
#  'Kasterleepark',
#  'Kr锟絣ler-M锟絣lerpark',
#  'Lutkemeerpark',
#  'Martin Luther Kingpark',
#  'Meerpark',
#  'Nelson Mandelapark',
#  'Noorderpark',
#  'Oeverpark',
#  'Oostenburgerpark',
#  'Oosterpark',
#  'Oosterparkbuurt',
#  'Overhoeksparklaan',
#  'Park De Kuil',
#  'Park Frankendael',
#  'Park Somerlust',
#  'Piet Wiedijkpark',
#  'Prins Bernhardpark',
#  'Proefeilandpark',
#  'Professor Joop van Stigtpark',
#  'Q Plaza park',
#  'Rembrandtpark',
#  'Rembrandtpark Noord',
#  'Rembrandtpark Zuid',
#  'Rietlandpark',
#  'Sarphatipark',
#  'Schegpark (tijdelijk)',
#  'Schellingwouderpark',
# ...

# %%
#Top 6 biggest parks
locations = ['Rembrandtpark Noord',
 'Rembrandtpark Zuid',
 'Sarphatipark',
 'Vondelpark Oost',
 'Vondelpark West',
 'Oosterpark',
 'Erasmuspark',
 'Westergasfabriek']

# %%
# Only select resono data of biggest 6 parks
df_average_visits_parks = df_average_visits[df_average_visits['Location'].isin(locations)]

# Merge Noord-Zuid & Oost-West into one location
df_average_visits_parks.loc[df_average_visits_parks.Location.str.contains('Rembrandtpark'), 'Location'] = 'Rembrandtpark'
df_average_visits_parks.loc[df_average_visits_parks.Location.str.contains('Vondelpark'), 'Location'] = 'Vondelpark'

df_average_visits_parks_summed = df_average_visits_parks.groupby(['Location', 'Start']).sum().reset_index()
# Out:
# C:\Users\lotte\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
sns.lineplot(x="Start", y="Visits", hue="Location", data=df_average_visits_parks_summed)
# Out:
# <AxesSubplot:xlabel='Start', ylabel='Visits'>

# %% [markdown]
# # Augment the data

# %%
# Group data and rename a couple of the columns
data = df_average_visits_parks.groupby(['Location', 'Start', 'Start_Dates', 'Start_Time']).sum().reset_index()
data = data.rename(columns = {'Start' : 'Datetime',
                              'Start_Dates' : 'Date',
                              'Start_Time' : 'Time'})
data = data.set_index('Datetime')
data
# Out:
#                                    Location        Date      Time  Visits
# Datetime
# 2020-09-30 00:00:00+00:00       Erasmuspark  2020-09-30  00:00:00    71.0
# 2020-09-30 00:15:00+00:00       Erasmuspark  2020-09-30  00:15:00    56.0
# 2020-09-30 00:30:00+00:00       Erasmuspark  2020-09-30  00:30:00    41.5
# 2020-09-30 00:45:00+00:00       Erasmuspark  2020-09-30  00:45:00    55.5
# 2020-09-30 01:00:00+00:00       Erasmuspark  2020-09-30  01:00:00    33.5
# ...                                     ...         ...       ...     ...
# 2020-11-12 11:45:00+00:00  Westergasfabriek  2020-11-12  11:45:00  1881.0
# 2020-11-12 12:00:00+00:00  Westergasfabriek  2020-11-12  12:00:00  1501.0
# 2020-11-12 12:15:00+00:00  Westergasfabriek  2020-11-12  12:15:00  1204.0
# 2020-11-12 12:30:00+00:00  Westergasfabriek  2020-11-12  12:30:00   813.0
# 2020-11-12 12:45:00+00:00  Westergasfabriek  2020-11-12  12:45:00  1097.0
#
# [43822 rows x 4 columns]

# %%
def add_weekday_month(data, date):
    """
    Adds columns for the month and weekday, and also the cyclical versions of those features.

    :data: Dataframe that contains the a column with the date in format 'YYYY-MM-DD'
    :date: Name of the column that contains the date
    :return: Dataframe with the sine and cosine of the weekday and month added
    """ 
    dates = data[date].values
    weekdays = []
    months = []

    for t in dates:
        year, month, day = (int(x) for x in t.split('-'))
        ans = dt.date(year, month, day)
        weekdays.append(ans.isocalendar()[2])
        months.append(month)

    data['Weekday'] = weekdays
    data['Month'] = months
    data['Weekday_sin'] = np.sin(data['Weekday'] * (2 * np.pi / 7))
    data['Weekday_cos'] = np.cos(data['Weekday'] * (2 * np.pi / 7))
    data['Month_sin'] = np.sin(data['Month'] * (2 * np.pi / 12))
    data['Month_cos'] = np.cos(data['Month'] * (2 * np.pi / 12))
    return data

data = add_weekday_month(data, 'Date')
data
# Out:
#                                    Location        Date      Time  Visits  \
# Datetime
# 2020-09-30 00:00:00+00:00       Erasmuspark  2020-09-30  00:00:00    71.0
# 2020-09-30 00:15:00+00:00       Erasmuspark  2020-09-30  00:15:00    56.0
# 2020-09-30 00:30:00+00:00       Erasmuspark  2020-09-30  00:30:00    41.5
# 2020-09-30 00:45:00+00:00       Erasmuspark  2020-09-30  00:45:00    55.5
# 2020-09-30 01:00:00+00:00       Erasmuspark  2020-09-30  01:00:00    33.5
# ...                                     ...         ...       ...     ...
# 2020-11-12 11:45:00+00:00  Westergasfabriek  2020-11-12  11:45:00  1881.0
# 2020-11-12 12:00:00+00:00  Westergasfabriek  2020-11-12  12:00:00  1501.0
# 2020-11-12 12:15:00+00:00  Westergasfabriek  2020-11-12  12:15:00  1204.0
# 2020-11-12 12:30:00+00:00  Westergasfabriek  2020-11-12  12:30:00   813.0
# 2020-11-12 12:45:00+00:00  Westergasfabriek  2020-11-12  12:45:00  1097.0
#
# ...

# %% [markdown]
# # Predictions with XGBoost

# %%
def predict(data, location, pred_params):
    """
    Predict the amount of visits using XGBoost
    
    :data: Dataframe with all the data
    :location: The location of the park to make predictions for
    :pred_params: A list of the names of the predictor variables
    :return: Nothing
    """
    # Select data for a specific park
    data = data[data['Location'] == location]

    # Split the data into input and output variables
    X = data[pred_params]
    y = data['Visits']

    # Split the data into test and train sets
    train_X, test_X, train_y, test_y = train_test_split(X, y,
                          test_size = 0.3, random_state = 123)

    # Convert test and train set to DMatrix objects
    train_dmatrix = xgb.DMatrix(data = train_X, label = train_y)
    test_dmatrix = xgb.DMatrix(data = test_X, label = test_y)
    
    # Set parameters for base learner
    param = {"booster":"gblinear", "objective":"reg:squarederror"}
    
    # Fit the data and make predictions
    model = xgb.train(params = param, dtrain = train_dmatrix, num_boost_round = 10)
    pred = model.predict(test_dmatrix)
    
    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(test_y, pred))
    print("RMSE : % f" %(rmse))
    
    
predict(data, 'Vondelpark', ['Weekday_sin', 'Weekday_cos', 'Month_sin', 'Month_cos'])
# Out:
# RMSE :  1347.127540
